# %% [markdown]
# # Test PostgreSQL Connection

# %%
from src.db.connection import get_connection
conn = get_connection()

print('Connection successful')
conn.close()
# Out:
# Connection successful

# %% [markdown]
# # Check Tables Exist

# %%
from src.db.connection import get_connection

conn = get_connection()
cur = conn.cursor()

cur.execute("""
SELECT table_name
FROM information_schema.tables
WHERE table_schema = 'public';
""")

tables = cur.fetchall()
print('Tables found:', tables)

cur.close()
conn.close()
# Out:
# Tables found: [('feedback',), ('campaign_product',), ('sales',)]

# %% [markdown]
# # Test CSV Ingestion

# %%
from src.ingestion.load_csv import load_campaign_products, load_sales

load_campaign_products("campaign_product_test.csv")
load_sales("sales_test.csv")

# %% [markdown]
# # Test JSON Feedback Ingestion

# %%
from src.ingestion.load_feedback_json import load_feedback_json

load_feedback_json("data/raw/feedbacks/feedbacks_raw.json")

# %% [markdown]
# # Verify Data in PostgreSQL

# %%
from src.db.connection import get_connection

conn = get_connection()
cur = conn.cursor()

cur.execute("SELECT * FROM sales;")
cur.execute("SELECT * FROM campaign_product;")
cur.execute("SELECT * FROM feedback;")

rows = cur.fetchall()

for row in rows:
    print(row)

cur.close()
conn.close()
# Out:
# (1, 'user_907', datetime.date(2025, 5, 28), 'CAMP940', 'Loved the product presentation.')
# (2, 'user_2899', datetime.date(2024, 9, 2), 'CAMP855', '素晴らしいキャンペーンです！')
# (3, 'user_3970', datetime.date(2024, 1, 4), 'CAMP742', 'あまり惹きつけられないです。')
# (4, 'user_2260', datetime.date(2025, 12, 18), 'CAMP491', 'इसे और बेहतर तरीके से संगठित किया जा सकता है।')
# (5, 'user_4077', datetime.date(2025, 7, 28), 'CAMP861', '素晴らしいキャンペーンです！')
# (6, 'user_4263', datetime.date(2025, 1, 1), 'CAMP290', 'इसे और बेहतर तरीके से संगठित किया जा सकता है।')
# (7, 'user_35', datetime.date(2026, 4, 9), 'CAMP592', 'Could be better organized.')
# (8, 'user_4548', datetime.date(2025, 12, 14), 'CAMP347', 'बहुत ज़्यादा विवरण हैं, समझना मुश्किल है।')
# (9, 'user_329', datetime.date(2024, 2, 12), 'CAMP161', 'Could be better organized.')
# (10, 'user_4660', datetime.date(2026, 6, 11), 'CAMP279', 'Excellente stratégie marketing.')
# (11, 'user_1808', datetime.date(2026, 9, 9), 'CAMP661', 'इसे और बेहतर तरीके से संगठित किया जा सकता है।')
# (12, 'user_2864', datetime.date(2025, 10, 24), 'CAMP187', 'もっと整理できると思います。')
# (13, 'user_1531', datetime.date(2025, 4, 6), 'CAMP584', 'Excellente campagne !')
# (14, 'user_2654', datetime.date(2024, 2, 8), 'CAMP951', '有创意又有趣的方法！')
# (15, 'user_3492', datetime.date(2026, 10, 5), 'CAMP820', '组织得可以更好一些。')
# (16, 'user_4463', datetime.date(2024, 2, 1), 'CAMP986', 'Not very engaging.')
# (17, 'user_4227', datetime.date(2024, 12, 15), 'CAMP918', 'Excellente stratégie marketing.')
# (18, 'user_4740', datetime.date(2026, 9, 19), 'CAMP212', 'Too many details, hard to follow.')
# (19, 'user_187', datetime.date(2024, 6, 17), 'CAMP446', 'रचनात्मक और मज़ेदार तरीका!')
# (20, 'user_4048', datetime.date(2024, 10, 5), 'CAMP560', 'Clear and concise message.')
# (21, 'user_2502', datetime.date(2024, 10, 8), 'CAMP307', 'Creative and fun approach!')
# (22, 'user_3155', datetime.date(2025, 9, 9), 'CAMP317', 'もっと整理できると思います。')
# (23, 'user_3939', datetime.date(2026, 2, 6), 'CAMP4', 'बेहतरीन अभियान!')
# (24, 'user_4590', datetime.date(2026, 2, 25), 'CAMP486', '優れたマーケティング戦略です。')
# (25, 'user_722', datetime.date(2026, 10, 26), 'CAMP734', '素晴らしいキャンペーンです！')
# (26, 'user_907', datetime.date(2025, 5, 28), 'CAMP940', 'Loved the product presentation.')
# (27, 'user_2899', datetime.date(2024, 9, 2), 'CAMP855', '素晴らしいキャンペーンです！')
# (28, 'user_3970', datetime.date(2024, 1, 4), 'CAMP742', 'あまり惹きつけられないです。')
# (29, 'user_2260', datetime.date(2025, 12, 18), 'CAMP491', 'इसे और बेहतर तरीके से संगठित किया जा सकता है।')
# (30, 'user_4077', datetime.date(2025, 7, 28), 'CAMP861', '素晴らしいキャンペーンです！')
# (31, 'user_4263', datetime.date(2025, 1, 1), 'CAMP290', 'इसे और बेहतर तरीके से संगठित किया जा सकता है।')
# (32, 'user_35', datetime.date(2026, 4, 9), 'CAMP592', 'Could be better organized.')
# (33, 'user_4548', datetime.date(2025, 12, 14), 'CAMP347', 'बहुत ज़्यादा विवरण हैं, समझना मुश्किल है।')
# (34, 'user_329', datetime.date(2024, 2, 12), 'CAMP161', 'Could be better organized.')
# (35, 'user_4660', datetime.date(2026, 6, 11), 'CAMP279', 'Excellente stratégie marketing.')
# (36, 'user_1808', datetime.date(2026, 9, 9), 'CAMP661', 'इसे और बेहतर तरीके से संगठित किया जा सकता है।')
# (37, 'user_2864', datetime.date(2025, 10, 24), 'CAMP187', 'もっと整理できると思います。')
# (38, 'user_1531', datetime.date(2025, 4, 6), 'CAMP584', 'Excellente campagne !')
# (39, 'user_2654', datetime.date(2024, 2, 8), 'CAMP951', '有创意又有趣的方法！')
# (40, 'user_3492', datetime.date(2026, 10, 5), 'CAMP820', '组织得可以更好一些。')
# (41, 'user_4463', datetime.date(2024, 2, 1), 'CAMP986', 'Not very engaging.')
# (42, 'user_4227', datetime.date(2024, 12, 15), 'CAMP918', 'Excellente stratégie marketing.')
# (43, 'user_4740', datetime.date(2026, 9, 19), 'CAMP212', 'Too many details, hard to follow.')
# (44, 'user_187', datetime.date(2024, 6, 17), 'CAMP446', 'रचनात्मक और मज़ेदार तरीका!')
# (45, 'user_4048', datetime.date(2024, 10, 5), 'CAMP560', 'Clear and concise message.')
# (46, 'user_2502', datetime.date(2024, 10, 8), 'CAMP307', 'Creative and fun approach!')
# (47, 'user_3155', datetime.date(2025, 9, 9), 'CAMP317', 'もっと整理できると思います。')
# (48, 'user_3939', datetime.date(2026, 2, 6), 'CAMP4', 'बेहतरीन अभियान!')
# (49, 'user_4590', datetime.date(2026, 2, 25), 'CAMP486', '優れたマーケティング戦略です。')
# (50, 'user_722', datetime.date(2026, 10, 26), 'CAMP734', '素晴らしいキャンペーンです！')
